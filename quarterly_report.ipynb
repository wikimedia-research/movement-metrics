# %%
import src.utils as utils

# %%
metrics = utils.load_all_metric_files()

# %%
quarterly_averages = metrics.resample("Q-JUN").mean()

# %%
(
    quarterly_averages
    # This column has recent zero values which cause problems
    .drop(["unclassed_unique_devices"], axis="columns")
    .apply(utils.calc_rpt)
    .T
)
# Out:
#                                                       value  \
# central_eastern_europe_central_asia_unique_devices  188.0 M
# east_southeast_asia_pacific_unique_devices          268.0 M
# latin_america_caribbean_unique_devices              135.0 M
# middle_east_north_africa_unique_devices              66.5 M
# north_america_unique_devices                        310.0 M
# northern_western_europe_unique_devices              357.0 M
# south_asia_unique_devices                           161.0 M
# subsaharan_africa_unique_devices                     35.3 M
# unknown_unique_devices                              413,000
# automated_pageviews                                  2.87 B
# desktop                                              5.61 B
# interactions                                         20.3 B
# mobileweb                                            12.8 B
# previews_seen                                        1.57 B
# total_pageview                                       18.8 B
# ...
