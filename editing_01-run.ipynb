# %%
#step 0 - git pull to stay up to date with the repo on Github
#Step 1 - make sure that there's data on the API --- see emails in the product analytics email account
#Step 2 - run the four notebooks noted below on a stat box

# %%
# %run 'editing_02a-calculation.ipynb'
# Out:
# You are using Wmfdata v2.0.0, but v2.0.1 is available.
#
# To update, run `pip install --upgrade git+https://github.com/wikimedia/wmfdata-python.git@release`.
#
# To see the changes, refer to https://github.com/wikimedia/wmfdata-python/blob/release/CHANGELOG.md.
# Running active_editors on hive...
# SPARK_HOME: /usr/lib/spark3
# Using Hadoop client lib jars at 3.2.0, provided by Spark.
# PYSPARK_PYTHON=/opt/conda-analytics/bin/python3
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/09/22 15:20:26 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# 23/09/22 15:20:26 WARN Utils: Service 'sparkDriver' could not bind on port 12000. Attempting port 12001.
# 23/09/22 15:20:26 WARN Utils: Service 'sparkDriver' could not bind on port 12001. Attempting port 12002.
# 23/09/22 15:20:26 WARN Utils: Service 'sparkDriver' could not bind on port 12002. Attempting port 12003.
# 23/09/22 15:20:26 WARN Utils: Service 'sparkDriver' could not bind on port 12003. Attempting port 12004.
# 23/09/22 15:20:27 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 23/09/22 15:20:27 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 23/09/22 15:20:27 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 23/09/22 15:20:27 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 23/09/22 15:20:38 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13000. Attempting port 13001.
# 23/09/22 15:20:38 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13001. Attempting port 13002.
# 23/09/22 15:20:38 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13002. Attempting port 13003.
# 23/09/22 15:20:38 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13003. Attempting port 13004.
# 23/09/22 15:20:38 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Attempted to request executors before the AM has registered!
# 23/09/22 15:20:52 WARN SharedInMemoryCache: Evicting cached table partition metadata from memory due to size constraints (spark.sql.hive.filesourcePartitionFileCacheSize = 262144000 bytes). This may impact query planning performance.
# Running edits on hive...
# 23/09/22 15:21:28 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# Running new_editor_retention on hive...
# Running global_south_edits_editors on hive...
# Running mobile-heavy_edits_editors on hive...
# Running mobile-heavy_new_editor_retention on hive...
# Running global_south_new_editor_retention on hive...
# Now on the 0th project of 335 (aa.wikipedia.org)
# Now on the 10th project of 335 (ang.wikipedia.org)
# Now on the 20th project of 335 (avk.wikipedia.org)
# Now on the 30th project of 335 (bcl.wikipedia.org)
# Now on the 40th project of 335 (bo.wikipedia.org)
# Now on the 50th project of 335 (ce.wikipedia.org)
# Now on the 60th project of 335 (cs.wikipedia.org)
# Now on the 70th project of 335 (dty.wikipedia.org)
# Now on the 80th project of 335 (eu.wikipedia.org)
# Now on the 90th project of 335 (frr.wikipedia.org)
# Now on the 100th project of 335 (gl.wikipedia.org)
# Now on the 110th project of 335 (gv.wikipedia.org)
# Now on the 120th project of 335 (ht.wikipedia.org)
# Now on the 130th project of 335 (ik.wikipedia.org)
# Now on the 140th project of 335 (jv.wikipedia.org)
# Now on the 150th project of 335 (kk.wikipedia.org)
# Now on the 160th project of 335 (ku.wikipedia.org)
# Now on the 170th project of 335 (lg.wikipedia.org)
# Now on the 180th project of 335 (lv.wikipedia.org)
# Now on the 190th project of 335 (mk.wikipedia.org)
# Now on the 200th project of 335 (mwl.wikipedia.org)
# Now on the 210th project of 335 (new.wikipedia.org)
# Now on the 220th project of 335 (nv.wikipedia.org)
# Now on the 230th project of 335 (pa.wikipedia.org)
# Now on the 240th project of 335 (pnt.wikipedia.org)
# Now on the 250th project of 335 (ro.wikipedia.org)
# Now on the 260th project of 335 (sd.wikipedia.org)
# Now on the 270th project of 335 (sl.wikipedia.org)
# Now on the 280th project of 335 (st.wikipedia.org)
# Now on the 290th project of 335 (te.wikipedia.org)
# Now on the 300th project of 335 (trv.wikipedia.org)
# Now on the 310th project of 335 (uk.wikipedia.org)
# Now on the 320th project of 335 (wa.wikipedia.org)
# Now on the 330th project of 335 (zh-classical.wikipedia.org)
#             active_editors  anonymous_edits  global_south_active_editors  \
# month
# 2023-04-01  91004.0         1961180.0        20411.0
# 2023-05-01  91711.0         2002114.0        20267.0
# 2023-06-01  87961.0         1895243.0        20214.0
# 2023-07-01  87888.0         1880484.0        20178.0
# 2023-08-01  88060.0         1870043.0        20131.0
#
#             global_south_edits  global_south_new_editor_retention  \
# month
# 2023-04-01  2978178.0          NaN
# 2023-05-01  2828472.0          NaN
# 2023-06-01  3098878.0          NaN
# 2023-07-01  3383710.0          NaN
# 2023-08-01  3090207.0          NaN
#
#             global_south_nonbot_edits  mobile-heavy_wiki_active_editors  \
# month
# 2023-04-01  2689331.0                  5253.0
# 2023-05-01  2582733.0                  5283.0
# 2023-06-01  2519935.0                  5411.0
# 2023-07-01  2693299.0                  5070.0
# 2023-08-01  2787276.0                  5090.0
#
#             mobile-heavy_wiki_edits  mobile-heavy_wiki_new_editor_retention  \
# month
# 2023-04-01  880299.0                 0.054568
# 2023-05-01  990895.0                 0.055442
# 2023-06-01  947840.0                 0.057196
# 2023-07-01  1185634.0                0.054265
# 2023-08-01  1222563.0                0.049041
#
#             mobile-heavy_wiki_nonbot_edits  mobile_edits  \
# month
# 2023-04-01  510863.0                        2036253.0
# 2023-05-01  515371.0                        2130238.0
# 2023-06-01  523348.0                        2092098.0
# 2023-07-01  526894.0                        2234879.0
# 2023-08-01  540844.0                        2298911.0
#
#             net_new_Commons_content_pages  net_new_Wikidata_entities  \
# month
# 2023-04-01  796965.0                       480902.0
# 2023-05-01  806293.0                       779698.0
# 2023-06-01  950689.0                       1139939.0
# 2023-07-01  1305360.0                      903759.0
# 2023-08-01  1090121.0                      962798.0
#
#             net_new_Wikipedia_articles  net_new_content_pages  \
# month
# 2023-04-01  216111.0                    1841465.0
# 2023-05-01  202301.0                    3211236.0
# 2023-06-01  160329.0                    2882786.0
# 2023-07-01  157392.0                    2729635.0
# 2023-08-01  164588.0                    2872486.0
#
#             new_active_editors  new_editor_retention  non_anonymous_edits  \
# month
# 2023-04-01  17002.0             0.070166              45754123.0
# 2023-05-01  16974.0             0.067278              48036537.0
# 2023-06-01  16208.0             0.061469              46400660.0
# 2023-07-01  15678.0             0.058309              42620027.0
# 2023-08-01  15103.0             0.057988              45475870.0
#
#             other_nonbot_edits  returning_active_editors  revert_rate  \
# month
# 2023-04-01  11044883.0          74002.0                   0.056774
# 2023-05-01  10815482.0          74737.0                   0.063386
# 2023-06-01  10181672.0          71753.0                   0.049638
# 2023-07-01  10590389.0          72210.0                   0.043783
# 2023-08-01  10778493.0          72957.0                   0.044715
#
#             total_edits    uploads  wikidata_edits
# month
# 2023-04-01  47715591.0   846514.0   20169473.0
# 2023-05-01  50038842.0   852157.0   19492792.0
# 2023-06-01  48296199.0   1008563.0  20461438.0
# 2023-07-01  44506144.0   1352608.0  16854315.0
# 2023-08-01  47350800.0   1137635.0  21763128.0

# %%
# %run 'editing_02b-diversity-calculation.ipynb'
# Out:
# Running global_south_edits_editors on hive...
# /home/osefu/.conda/envs/2023-09-21T22.51.44_osefu/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_south_new_editor_retention on hive...
# /home/osefu/.conda/envs/2023-09-21T22.51.44_osefu/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_south_net_new_content on hive...
# /home/osefu/.conda/envs/2023-09-21T22.51.44_osefu/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_south_wikidata_entities on hive...
# /home/osefu/.conda/envs/2023-09-21T22.51.44_osefu/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_north_edits_editors on hive...
# /home/osefu/.conda/envs/2023-09-21T22.51.44_osefu/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_north_new_editor_retention on hive...
# /home/osefu/.conda/envs/2023-09-21T22.51.44_osefu/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_north_net_new_content on hive...
# /home/osefu/.conda/envs/2023-09-21T22.51.44_osefu/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_north_wikidata_entities on hive...
# /home/osefu/.conda/envs/2023-09-21T22.51.44_osefu/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#             global_north_active_editors  global_north_edits  \
# month
# 2023-04-01  60511.0                      22506527.0
# 2023-05-01  61101.0                      23831841.0
# 2023-06-01  57764.0                      22830501.0
# 2023-07-01  58023.0                      20084763.0
# 2023-08-01  59078.0                      21124260.0
#
#             global_north_net_new_content  global_north_new_editor_retention  \
# month
# 2023-04-01  1339595.0                    NaN
# 2023-05-01  2439208.0                    NaN
# 2023-06-01  2207643.0                    NaN
# 2023-07-01  2229434.0                    NaN
# 2023-08-01  2298140.0                    NaN
#
#             global_north_nonbot_edits  global_north_wikidata_entities  \
# month
# 2023-04-01  12251552.0                 421655.0
# 2023-05-01  12512159.0                 686609.0
# 2023-06-01  12398239.0                 986442.0
# 2023-07-01  13201391.0                 872197.0
# 2023-08-01  13199738.0                 927274.0
#
#             global_south_active_editors  global_south_edits  \
# month
# 2023-04-01  20411.0                      2978178.0
# 2023-05-01  20267.0                      2828472.0
# 2023-06-01  20214.0                      3098878.0
# 2023-07-01  20178.0                      3383710.0
# 2023-08-01  20131.0                      3090207.0
#
#             global_south_net_new_content  global_south_new_editor_retention  \
# month
# 2023-04-01  373579.0                     NaN
# 2023-05-01  252402.0                     NaN
# 2023-06-01  847306.0                     NaN
# 2023-07-01  356479.0                     NaN
# 2023-08-01  264747.0                     NaN
#
#             global_south_nonbot_edits  global_south_wikidata_entities
# month
# 2023-04-01  2689331.0                  41170.0
# 2023-05-01  2582733.0                  25832.0
# 2023-06-01  2519935.0                  604070.0
# 2023-07-01  2693299.0                  24088.0
# 2023-08-01  2787276.0                  23658.0

# %%
# TODO get ouput here 
# see the report here: https://github.com/wikimedia-research/Editing-movement-metrics/blob/master/03a-report.ipynb
# %run 'editing_03a-report.ipynb'
# Out:
# Previous month's report

# %%
# see the viz repo for further documentation: https://github.com/wikimedia-research/key_product_metrics/ 
# data_path = "../metrics/metrics.tsv"
# chart files can be accessed here: https://github.com/wikimedia-research/Editing-movement-metrics/charts
# %run '../key_product_metrics/wikicharts/EDITOR_METRICS.ipynb'
# Out:
# Changing directory to:/srv/home/osefu/key_product_metrics/wikicharts
# Generating Active Editors chart...
# Generating New Returning chart...
# Generating Net New Content chart...
# Resetting directory to:/srv/home/osefu/key_product_metrics/wikicharts

# %%
# proceed to step 4 as noted in the readme file
