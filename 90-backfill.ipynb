# %% [markdown]
# This notebook can be used to backfill new or changed metrics across all history (unlike `03-report.ipynb` which runs all metrics for a single month). To do a new backfill, overwrite this code, run your backfill, and then commit the notebook to Git (so it can be overwritten for the next backfill).

# %%
import pandas as pd
from wmfdata import hive

# %%
FILENAME = "metrics/metrics.tsv"

# old metric column names (to be removed)
OLD_COLUMNS = [
    "total_edits",
    "uploads",
    "mobile_edits",
    "data_edits",
    "nonbot_nondata_nonupload_edits",
    "revert_rate"
]

MEDIAWIKI_HISTORY_SNAPSHOT = "2019-04"

# %%
old_metrics = (
    pd.read_csv(FILENAME, sep="\t", parse_dates = ["month"])
    .set_index("month")
)

old_metrics[OLD_COLUMNS].tail()
# Out:
#             total_edits   uploads  mobile_edits  data_edits  \
# month
# 2018-11-01   44349706.0  592679.0     1228780.0  23908469.0
# 2018-12-01   41966740.0  551296.0     1260692.0  21426310.0
# 2019-01-01   46294961.0  587164.0     1416465.0  23223444.0
# 2019-02-01   44131944.0  534391.0           NaN  22674118.0
# 2019-03-01   49431409.0  547740.0           NaN  28497214.0
#
#             nonbot_nondata_nonupload_edits  revert_rate
# month
# 2018-11-01                      13563561.0     0.071465
# 2018-12-01                      13490420.0     0.065287
# 2019-01-01                      14917046.0     0.060343
# 2019-02-01                      13415954.0     0.060140
# 2019-03-01                      14459657.0     0.052600

# %%
old_metrics = old_metrics.drop(OLD_COLUMNS, axis=1)

# %%
new_metrics = hive.run("""
select
    date_format(event_timestamp, "yyyy-MM-01") as month,
    count(*) as total_edits,
    sum(cast(upload as int)) as uploads,
    sum(cast(mobile_edit as int)) as mobile_edits,
    sum(cast(data_edit as int)) as wikidata_edits,
    sum(cast(nonbot_edit and not data_edit and not upload and not mobile_edit as int)) as other_nonbot_edits,
    sum(cast(reverted as int)) / sum(cast(nonbot_edit as int)) as revert_rate
from (
    select
        event_timestamp,
        (
            array_contains(revision_tags, "mobile edit") or
            array_contains(revision_tags, "mobile app edit") or 
            array_contains(revision_tags, "mobile web edit")
        ) as mobile_edit,
        size(event_user_is_bot_by) = 0 and size(event_user_is_bot_by_historical) = 0 as nonbot_edit,
        (wiki_db = "wikidatawiki" and page_namespace_historical in (0, 120)) as data_edit,
        revision_is_identity_reverted as reverted,
        (revision_parent_id = 0 and page_namespace_historical = 6) as upload
    from wmf.mediawiki_history
    where
        event_timestamp between "2001-01-01" and "2019-04-01" and
        event_entity = "revision" and
        event_type = "create" and
        snapshot = "{mediawiki_history_snapshot}"
) edits
group by date_format(event_timestamp, "yyyy-MM-01")
""".format(mediawiki_history_snapshot=MEDIAWIKI_HISTORY_SNAPSHOT)
)

# %%
new_metrics = (
    new_metrics
    .sort_values("month")
    .assign(month=lambda df: pd.to_datetime(df["month"]))
    .set_index("month")
)

# %%
new_metrics.head()
# Out:
#             total_edits  uploads  mobile_edits  wikidata_edits  \
# month
# 2001-01-01        13783        0             0               0
# 2001-02-01         2178        0             0               0
# 2001-03-01         4078        0             0               0
# 2001-04-01         2735        0             0               0
# 2001-05-01         5955        0             0               0
#
#             other_nonbot_edits  revert_rate
# month
# 2001-01-01                 225     0.014760
# 2001-02-01                 600     0.001362
# 2001-03-01                1018     0.000818
# 2001-04-01                 759     0.003322
# 2001-05-01                1698     0.001532

# %%
new_metrics.tail()
# Out:
#             total_edits  uploads  mobile_edits  wikidata_edits  \
# month
# 2018-11-01     44376013   586129       1228949        23896534
# 2018-12-01     41988394   546299       1260737        21418466
# 2019-01-01     46312638   580719       1416777        23213770
# 2019-02-01     44135189   531456       1254935        22667003
# 2019-03-01     49434627   542547       1379133        28490299
#
#             other_nonbot_edits  revert_rate
# month
# 2018-11-01            11038500     0.093747
# 2018-12-01            10991655     0.085478
# 2019-01-01            12143464     0.081303
# 2019-02-01            10952758     0.073758
# 2019-03-01            11748062     0.063090

# %%
metrics = old_metrics.merge(new_metrics, left_index=True, right_index=True)

# %%
pd_display_all(metrics["2017":])
# Out:
#             active_editors  existing_active_editors  \
# month
# 2017-01-01  85498.0         62293.0
# 2017-02-01  80421.0         58230.0
# 2017-03-01  87486.0         62324.0
# 2017-04-01  82855.0         60268.0
# 2017-05-01  86186.0         61146.0
# 2017-06-01  81664.0         57870.0
# 2017-07-01  80149.0         58758.0
# 2017-08-01  79186.0         59160.0
# 2017-09-01  79610.0         58173.0
# 2017-10-01  81073.0         59620.0
# 2017-11-01  82743.0         60452.0
# 2017-12-01  79558.0         60147.0
# 2018-01-01  84422.0         63442.0
# 2018-02-01  78963.0         58887.0
# 2018-03-01  86190.0         63332.0
# 2018-04-01  83705.0         62042.0
# 2018-05-01  85424.0         62698.0
# 2018-06-01  78549.0         59034.0
# 2018-07-01  77734.0         59386.0
# 2018-08-01  78681.0         60371.0
# 2018-09-01  82084.0         59265.0
# 2018-10-01  82567.0         60815.0
# 2018-11-01  82584.0         61330.0
# 2018-12-01  81075.0         61161.0
# 2019-01-01  86776.0         65161.0
# 2019-02-01  82554.0         61981.0
# 2019-03-01  87711.0         65639.0
#
#             global_south_active_editors  global_south_edits  \
# month
# 2017-01-01 NaN                          NaN
# 2017-02-01 NaN                          NaN
# 2017-03-01 NaN                          NaN
# 2017-04-01 NaN                          NaN
# 2017-05-01 NaN                          NaN
# 2017-06-01 NaN                          NaN
# 2017-07-01 NaN                          NaN
# 2017-08-01 NaN                          NaN
# 2017-09-01 NaN                          NaN
# 2017-10-01 NaN                          NaN
# 2017-11-01 NaN                          NaN
# 2017-12-01 NaN                          NaN
# 2018-01-01 NaN                          NaN
# 2018-02-01 NaN                          NaN
# 2018-03-01 NaN                          NaN
# 2018-04-01 NaN                          NaN
# 2018-05-01 NaN                          NaN
# 2018-06-01 NaN                          NaN
# 2018-07-01 NaN                          NaN
# 2018-08-01 NaN                          NaN
# 2018-09-01  20109.0                      2070328.0
# 2018-10-01  19891.0                      1979771.0
# 2018-11-01  20008.0                      2015177.0
# 2018-12-01  20359.0                      2067577.0
