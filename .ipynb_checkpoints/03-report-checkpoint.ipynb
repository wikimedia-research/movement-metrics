# %%
from functools import reduce

from cycler import cycler
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
from numbers import Number
import numpy as np
import pandas as pd
#from scipy import stats as sstats
import wmfdata as wmf
from wmfdata.utils import pct_str, sig_figs
from wmfdata.charting import pct_fmt, M_fmt, comma_fmt

import gspread
from google.oauth2.service_account import Credentials

# %%
# %matplotlib inline
wmf.charting.set_mpl_style()

# %%
FILE = "metrics/metrics.tsv"
metrics = pd.read_csv(FILE, sep="\t", parse_dates=["month"]).set_index("month")

FILE_D =  "metrics/diversity_metrics.tsv"
diversity_metrics = pd.read_csv(FILE_D, sep="\t", parse_dates=["month"]).set_index("month")

graph_end = metrics.index[-1]
graph_start = graph_end - relativedelta(months = 47)

# %% [markdown]
# # Data transformation

# %%
# Transform content flows into content stocks
def stock_to_flow(arr):
    return arr[-1] - arr[0]

flow_cols = [
    "net_new_content_pages", 
    "net_new_Wikipedia_articles", 
    "net_new_Commons_content_pages", 
    "net_new_Wikidata_entities"
]
stock_cols = [
    "content_pages", 
    "Wikipedia_articles", 
    "Commons_content_pages",
    "Wikidata_entities"
]

name_map = {flow_cols[i]: stock_cols[i] for i in range(len(stock_cols))}

stock_metrics = metrics[flow_cols].cumsum().rename(name_map, axis=1)

metrics = pd.concat([metrics, stock_metrics], axis=1)

# Show results
metrics.tail()
# Out:
#             active_editors  anonymous_edits  global_south_active_editors  \
# month
# 2020-07-01         87691.0        2087988.0                      23467.0
# 2020-08-01         89195.0        2154040.0                      23465.0
# 2020-09-01         89403.0        2158528.0                      22523.0
# 2020-10-01         90946.0        2279491.0                      22782.0
# 2020-11-01         91778.0        2224357.0                      22179.0
#
#             global_south_edits  global_south_new_editor_retention  \
# month
# 2020-07-01           3133019.0                           0.042145
# 2020-08-01           3401090.0                           0.045110
# 2020-09-01           2790520.0                           0.049883
# 2020-10-01           2607596.0                           0.049959
# 2020-11-01           2831597.0                           0.049783
#
#             global_south_nonbot_edits  mobile-heavy_wiki_active_editors  \
# month
# 2020-07-01                  2721998.0                            5356.0
# 2020-08-01                  2725391.0                            5254.0
# 2020-09-01                  2421673.0                            4823.0
# 2020-10-01                  2496046.0                            5005.0
# 2020-11-01                  2418354.0                            4994.0
#
#             mobile-heavy_wiki_edits  mobile-heavy_wiki_new_editor_retention  \
# month
# 2020-07-01                1496188.0                                0.045204
# 2020-08-01                1538137.0                                0.046242
# 2020-09-01                1328972.0                                0.051647
# 2020-10-01                1151598.0                                0.049236
# 2020-11-01                1199941.0                                0.048257
#
#             mobile-heavy_wiki_nonbot_edits  ...  other_nonbot_edits  \
# month                                       ...
# 2020-07-01                        799567.0  ...          11996820.0
# 2020-08-01                        684396.0  ...          12778521.0
# 2020-09-01                        567904.0  ...          12249107.0
# 2020-10-01                        595157.0  ...          12362794.0
# 2020-11-01                        562327.0  ...          12338738.0
#
#             returning_active_editors  revert_rate  total_edits    uploads  \
# month
# 2020-07-01                   69031.0     0.066772   46233269.0   801286.0
# 2020-08-01                   71490.0     0.061018   55272101.0   760785.0
# 2020-09-01                   71197.0     0.112536   64554789.0   719390.0
# 2020-10-01                   71567.0     0.060057   65240927.0   868769.0
# 2020-11-01                   73214.0     0.054979   40273842.0  1290742.0
#
#             wikidata_edits  content_pages  Wikipedia_articles  \
# month
# 2020-07-01      21846294.0    257628665.0          54869438.0
# 2020-08-01      25294195.0    259656049.0          55156660.0
# 2020-09-01      15736096.0    261554268.0          55380576.0
# 2020-10-01      15507565.0    263863864.0          55761344.0
# 2020-11-01      15431435.0    266445862.0          56052009.0
#
#             Commons_content_pages  Wikidata_entities
# month
# 2020-07-01             63709358.0         89370427.0
# 2020-08-01             64422408.0         90097563.0
# 2020-09-01             65086973.0         90745023.0
# 2020-10-01             65903291.0         91604963.0
# 2020-11-01             67136157.0         92299886.0
#
# [5 rows x 28 columns]

# %%
metrics_all = pd.concat([metrics, diversity_metrics], axis=1)
metrics_all  = metrics_all.loc[:,~metrics_all.columns.duplicated()]

# %% [markdown]
# # Report

# %%
report_order = [
     #Editors
    'active_editors',
        'new_active_editors',
        'returning_active_editors',
    'new_editor_retention',
    # Content
    'content_pages', 
        'Wikipedia_articles',
        'Commons_content_pages', 
        'Wikidata_entities',
    'net_new_content_pages',
        'net_new_Wikipedia_articles',
        'net_new_Commons_content_pages',
        'net_new_Wikidata_entities',
    'revert_rate',
    'total_edits',
        'mobile_edits',
        'wikidata_edits',
        'uploads',
        'other_nonbot_edits',
        'anonymous_edits',
        'non_anonymous_edits',
    #Diversity Content
    'global_north_net_new_content',
    'global_south_net_new_content',
    'global_north_edits',
    'global_south_edits',
    #Diversity Editors
    'global_north_active_editors',
    'global_south_active_editors',
    'global_north_new_editor_retention',
    'global_south_new_editor_retention'

]

# %%
def fmt_num(x):
    if isinstance(x, Number) and not pd.isnull(x):
        x = sig_figs(x, 3)
        
        if x < 5:
            return pct_str(x)
        else:
            return "{:,.0f}".format(x)
    else:
        return x

def calc_rpt(ser):   
    cur = ser[-1]
    
    try:
        yr_prev = ser[-13]
        yoy_change = (cur / yr_prev) - 1
    except IndexError:
        yoy_change = None
        
    try:
        cagr = (ser[-1] / ser[-48])**(1/4) - 1
    except IndexError:
        cagr = None
        
    
    res = [cur, yoy_change, cagr]
    return pd.Series(
        [fmt_num(n) for n in res],
        index=["value", "yoy_change", "4_yr_cagr"]
    )

# %%
(
    metrics_all
    .apply(calc_rpt)
    .transpose()
    .reindex(report_order)
    .fillna("—")
)
# Out:
#                                          value yoy_change 4_yr_cagr
# content_pages                      266,000,000      17.5%     17.5%
# Wikipedia_articles                  56,100,000       7.9%      6.8%
# Commons_content_pages               67,100,000      16.0%     16.9%
# Wikidata_entities                   92,300,000      32.4%     39.9%
# net_new_content_pages                2,580,000     -44.5%     13.5%
# net_new_Wikipedia_articles             291,000      37.4%     -9.4%
# net_new_Commons_content_pages        1,230,000      94.8%     12.5%
# net_new_Wikidata_entities              695,000     -80.8%     48.0%
# revert_rate                               5.5%      -8.8%    -12.7%
# total_edits                         40,300,000     -14.2%      8.0%
# mobile_edits                         1,760,000      14.5%     21.4%
# wikidata_edits                      15,400,000     -34.3%     10.9%
# uploads                              1,290,000      88.3%     12.6%
# other_nonbot_edits                  12,300,000      11.4%      2.7%
# anonymous_edits                      2,220,000       2.4%         —
# non_anonymous_edits                 38,000,000     -15.0%         —
# active_editors                          91,800       6.9%      3.2%
# new_active_editors                      18,600      10.8%      3.0%
# returning_active_editors                73,200       6.0%      3.3%
# new_editor_retention                      7.7%       0.1%      2.0%
# global_north_net_new_content         1,920,000      -0.6%         —
# global_south_net_new_content           488,000      24.0%         —
# global_north_edits                  21,100,000     -12.8%         —
# global_south_edits                   2,830,000     -34.7%         —
# global_north_active_editors             73,800      -6.3%         —
# global_south_active_editors             22,200     -13.7%         —
# global_north_new_editor_retention         9.6%          —         —
# global_south_new_editor_retention         5.0%          —         —

# %% [markdown]
# # Graphs

# %%
ax = metrics[["returning_active_editors", "new_active_editors"]][graph_start:graph_end].plot()
plt.gca().yaxis.set_major_formatter(comma_fmt)
y_top = plt.ylim()[1] * 1.1
plt.ylim(bottom=0, top=y_top)
plt.xlabel("")
plt.ylabel("editors per month");

# %%
custom_cyc = cycler('color', ['r', 'g', 'b', 'y']) + cycler('linestyle', ['-', '--', ':', '-.'])
content_types = metrics[["Wikipedia_articles", "Commons_content_pages", "Wikidata_entities"]]
content_ser = [tup[1] for tup in content_types.iteritems()]

other_content = reduce(lambda x, y: x - y, content_ser, metrics["content_pages"]).rename("other_content")
content = pd.concat(
    [content_types, other_content], 
    axis=1
).rename(
    columns=lambda name: name.replace("_", " ")
).rename(
    columns={"Commons content pages": "Commons files"}
)

ax.set_prop_cycle(custom_cyc)
ax = content[graph_start:graph_end].plot(style=['--', ':', '-', '-.'], linewidth=3)

ax.yaxis.set_major_formatter(M_fmt)
y_top = plt.ylim()[1] * 1.1
plt.ylim(bottom=0, top=y_top)
plt.xlabel("")
plt.ylabel("");

# %%
graph_cfg = {
    "active_editors": {
        "y_lab": "editors per month"
    },
    "content_pages": {
        "y_fmt": M_fmt,
    },
    "Wikipedia_articles": {
        "y_fmt": M_fmt,
    },
    "Wikidata_entities": {
        "y_fmt": M_fmt,
    },
    "Commons_content_pages": {
        "y_fmt": M_fmt,
    },
    "existing_active_editors": {
        "y_lab": "editors per month"
    },
    "new_active_editors": {
        "y_lab": "editors per month"
    },
    "second_month_active_editors": {
        "y_lab": "editors per month"
    },
    "total_edits": {
        "y_fmt": M_fmt,
        "y_lab": "edits per month"
    },
   
    "other_nonbot_edits": {
        "y_fmt": M_fmt,
        "y_lab": "edits per month",
        "title": "nonbot edits, excluding data and upload edits"
    },
    "new_editor_retention": {
        "y_fmt": pct_fmt,
        "y_lab": "% of new editors retained into 2nd month"
    },
    "revert_rate": {
        "y_fmt": pct_fmt,
        "y_lab": "% of non-bot edits reverted"
    },
    "uploads": {
        "y_lab": "uploads per month"
    },
    "data_edits": {
        "y_fmt": M_fmt,
        "y_lab": "edits per month"
    },
    "net_new_content_pages": {
        "y_fmt": M_fmt,
        "title": "net new content (main namespace pages + files)"
    },
    "net_new_Wikipedia_articles": {
    },
    "net_new_Commons_content_pages": {
        "title": "net new files on all projects"
    },
    "net_new_Wikidata_entities": {
    },
    "global_south_new_editor_retention": {
        "y_fmt": pct_fmt,
        "y_lab": "% of new editors retained into 2nd month"
    }
}

for name, col in metrics.reindex(report_order, axis=1).iteritems():
    cfg = graph_cfg.get(name, {})
    plt.figure()
    
    col[graph_start:graph_end].plot()

    plt.title(cfg.get("title", name.replace("_", " ")))
    plt.ylabel(cfg.get("y_lab", ""))
    plt.xlabel("")
    plt.gca().yaxis.set_major_formatter(cfg.get("y_fmt", comma_fmt))
    
    y_top = plt.ylim()[1] * 1.1
    plt.ylim(bottom=0, top=y_top)
    plt.show()
    plt.close()

# %% [markdown]
# # Update Google Sheet

# %%
FILE = "metrics/metrics.tsv"
all_metrics = pd.read_csv(FILE, sep="\t")


DIV_FILE = "metrics/diversity_metrics.tsv"
diversity_metrics = pd.read_csv(DIV_FILE, sep="\t")

# %%
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = Credentials.from_service_account_file('big-mender-274521-324384a764e2.json', scopes=scope)
gc = gspread.authorize(credentials)

# %%
all_metrics.iloc[-1,1:] = all_metrics.iloc[-1,1:].astype(float)
diversity_metrics.iloc[-1,1:] = diversity_metrics.iloc[-1,1:].astype(float)

# %%
@property
def sheet1(self):
    """Shortcut property for getting the first worksheet."""
    return self.get_worksheet(0)

# %%
wks1 = gc.open("editors").sheet1
new_metrics = all_metrics.iloc[-1,[0,1,12,13,14,15,16,17,19,20,21,22,23,24]].tolist()
wks1.append_row(new_metrics)
# Out:
# {'spreadsheetId': '1wfTtHjQP9Kj0WME15ESJ-4dSMGMpbtY8qOuDVcwZovQ',
#  'tableRange': 'metrics!E243',
#  'updates': {'spreadsheetId': '1wfTtHjQP9Kj0WME15ESJ-4dSMGMpbtY8qOuDVcwZovQ',
#   'updatedRange': 'metrics!E244:R244',
#   'updatedRows': 1,
#   'updatedColumns': 14,
#   'updatedCells': 14}}

# %%
wks2 = gc.open("editors").get_worksheet(1)
div_metrics = diversity_metrics.iloc[-1].tolist()
wks2.append_row(div_metrics)
# Out:
# {'spreadsheetId': '1wfTtHjQP9Kj0WME15ESJ-4dSMGMpbtY8qOuDVcwZovQ',
#  'tableRange': 'diversity_global_market!A1:M35',
#  'updates': {'spreadsheetId': '1wfTtHjQP9Kj0WME15ESJ-4dSMGMpbtY8qOuDVcwZovQ',
#   'updatedRange': 'diversity_global_market!A36:M36',
#   'updatedRows': 1,
#   'updatedColumns': 13,
#   'updatedCells': 13}}

# %%
wks3 = gc.open("editors").get_worksheet(2)
mh_metrics = all_metrics.iloc[-1,[0,6,7,8,9]].tolist()
wks3.append_row(mh_metrics)
# Out:
# {'spreadsheetId': '1wfTtHjQP9Kj0WME15ESJ-4dSMGMpbtY8qOuDVcwZovQ',
#  'tableRange': 'diversity_mobile_heavy!A1:E240',
#  'updates': {'spreadsheetId': '1wfTtHjQP9Kj0WME15ESJ-4dSMGMpbtY8qOuDVcwZovQ',
#   'updatedRange': 'diversity_mobile_heavy!A241:E241',
#   'updatedRows': 1,
#   'updatedColumns': 5,
#   'updatedCells': 5}}
