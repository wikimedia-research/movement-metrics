# %% [markdown]
# This notebook can be used to backfill new or changed metrics across all history (unlike `03-report.ipynb` which runs all metrics for a single month). To do a new backfill, overwrite this code, run your backfill, and then commit the notebook to Git (so it can be overwritten for the next backfill).

# %%
import pandas as pd
from wmfdata import hive
from wmfdata.utils import pd_display_all
# Out:
# You can find the source for `wmfdata` at https://github.com/neilpquinn/wmfdata

# %%
FILENAME = "metrics/metrics.tsv"
MEDIAWIKI_HISTORY_SNAPSHOT = "2019-08"

# %%
old_metrics = (
    pd.read_csv(FILENAME, sep="\t", parse_dates = ["month"])
    .set_index("month")
)

old_metrics.tail()
# Out:
#             active_editors  global_south_active_editors  global_south_edits  \
# month
# 2019-04-01         84358.0                      19941.0           2053568.0
# 2019-05-01         90211.0                      20841.0           2273855.0
# 2019-06-01         83541.0                      20093.0           2090806.0
# 2019-07-01         82586.0                      21197.0           2265222.0
# 2019-08-01         82362.0                      21218.0           2379622.0
#
#             global_south_new_editor_retention  global_south_nonbot_edits  \
# month
# 2019-04-01                           0.040104                  2052287.0
# 2019-05-01                           0.042966                  2272975.0
# 2019-06-01                           0.058605                  2090322.0
# 2019-07-01                           0.041208                  2264700.0
# 2019-08-01                           0.041587                  2379348.0
#
#             mobile-heavy_wiki_active_editors  mobile-heavy_wiki_edits  \
# month
# 2019-04-01                            3996.0                1412904.0
# 2019-05-01                            4195.0                1384712.0
# 2019-06-01                            4270.0                1262220.0
# 2019-07-01                            4657.0                1351814.0
# 2019-08-01                            4508.0                1267338.0
#
#             mobile-heavy_wiki_new_editor_retention  \
# month
# 2019-04-01                                0.043767
# 2019-05-01                                0.049625
# 2019-06-01                                0.048544
# 2019-07-01                                0.050682
# 2019-08-01                                0.049440
#
#             mobile-heavy_wiki_nonbot_edits  mobile_edits  ...  \
# month                                                     ...
# 2019-04-01                        414992.0     1356454.0  ...
# 2019-05-01                        460884.0     1493057.0  ...
# 2019-06-01                        452430.0     1461766.0  ...
# 2019-07-01                        497732.0     1495166.0  ...
# 2019-08-01                        491070.0     1567696.0  ...
#
#             net_new_Wikipedia_articles  net_new_content_pages  \
# month
# 2019-04-01                    268254.0              1782113.0
# 2019-05-01                    189506.0              1978179.0
# 2019-06-01                    213853.0              1806274.0
# 2019-07-01                    230322.0              2215023.0
# 2019-08-01                    212086.0              1931846.0
#
#             new_active_editors  new_editor_retention  other_nonbot_edits  \
# month
# 2019-04-01             15535.0              0.068630          10955991.0
# 2019-05-01             19323.0              0.067605          11728361.0
# 2019-06-01             17070.0              0.060932          10591175.0
# 2019-07-01             15469.0              0.049296          10832271.0
# 2019-08-01             15053.0              0.051692          11376862.0
#
#             returning_active_editors  revert_rate  total_edits   uploads  \
# month
# 2019-04-01                   68823.0     0.055778   51252861.0  616226.0
# 2019-05-01                   70888.0     0.059398   46847183.0  702372.0
# 2019-06-01                   66471.0     0.055568   40171410.0  549546.0
# 2019-07-01                   67117.0     0.053355   38251850.0  724922.0
# 2019-08-01                   67309.0     0.052111   37001864.0  548600.0
#
#             wikidata_edits
# month
# 2019-04-01      30126989.0
# 2019-05-01      23578489.0
# 2019-06-01      18588097.0
# 2019-07-01      17976086.0
# 2019-08-01      15640296.0
#
# [5 rows x 22 columns]

# %%
hive.run("""show partitions wmf.geoeditors_daily""")
# Out:
#        partition
# 0  month=2018-11
# 1  month=2018-12
# 2  month=2019-01
# 3  month=2019-02
# 4  month=2019-03
# 5  month=2019-04
# 6  month=2019-05
# 7  month=2019-06
# 8  month=2019-07
# 9  month=2019-08

# %%
# Calculate for months where the data is still available
gs_ner_r = hive.run("""
with gs_new_editors as (
    select
        ne.cohort as cohort,
        1st_month_edits,
        2nd_month_edits
    from neilpquinn.new_editors ne
    left join wmf.geoeditors_daily gd
    on
        ne.user_id = gd.user_fingerprint_or_id and
        ne.wiki = gd.wiki_db and
        ne.cohort = gd.month
    left join canonical_data.countries cdc
    on gd.country_code = cdc.iso_code
    where
        ne.cohort between "2018-11" and "2019-04" and
        gd.month between "2018-11" and "2019-04" and
        economic_region = "Global South"
    group by ne.cohort, user_name, wiki, 1st_month_edits, 2nd_month_edits
)
select
    cohort,
    sum(cast(2nd_month_edits >= 1 as int)) / count(*) as global_south_new_editor_retention
from gs_new_editors
group by cohort
""")

# %%
gs_ner = gs_ner_r.set_index("cohort")

# Add earlier values from our reports 
gs_ner.loc["2018-04"] = 0.044275
gs_ner.loc["2018-05"] = 0.042536
gs_ner.loc["2018-06"] = 0.047855
gs_ner.loc["2018-07"] = 0.048320
gs_ner.loc["2018-08"] = None
gs_ner.loc["2018-09"] = 0.042
gs_ner.loc["2018-10"] = 0.041

gs_ner = (
    gs_ner
    .reset_index()
    .sort_values("cohort")
    # Add two months to convert from cohort months to metrics months
    .assign(month=lambda df: (pd.PeriodIndex(df["cohort"].values, freq="M") + 2).to_timestamp())
    .drop("cohort", axis=1)
    .set_index("month")
)

gs_ner
# Out:
#             global_south_new_editor_retention
# month
# 2018-06-01                           0.044275
# 2018-07-01                           0.042536
# 2018-08-01                           0.047855
# 2018-09-01                           0.048320
# 2018-10-01                                NaN
# 2018-11-01                           0.042000
# 2018-12-01                           0.041000
# 2019-01-01                           0.038393
# 2019-02-01                           0.043472
# 2019-03-01                           0.045774
# 2019-04-01                           0.040104
# 2019-05-01                           0.042966

# %%
metrics = old_metrics.merge(gs_ner, left_index=True, right_index=True, how="left").sort_index(axis=1)

# %%
pd_display_all(metrics["2018":])
# Out:
#             active_editors  global_south_active_editors  global_south_edits  \
# month
# 2018-01-01  84383.0        NaN                          NaN
# 2018-02-01  78868.0        NaN                          NaN
# 2018-03-01  85892.0        NaN                          NaN
# 2018-04-01  83382.0        NaN                          NaN
# 2018-05-01  85018.0        NaN                          NaN
# 2018-06-01  78524.0        NaN                          NaN
# 2018-07-01  77980.0        NaN                          NaN
# 2018-08-01  78792.0        NaN                          NaN
# 2018-09-01  82328.0         20109.0                      2070328.0
# 2018-10-01  82405.0         19891.0                      1979771.0
# 2018-11-01  82235.0         20008.0                      2015177.0
# 2018-12-01  80796.0         20359.0                      2067577.0
# 2019-01-01  86782.0         21367.0                      2434941.0
# 2019-02-01  82554.0         19743.0                      2241877.0
# 2019-03-01  87711.0         21679.0                      2294512.0
# 2019-04-01  84358.0         19941.0                      2053568.0
# 2019-05-01  90211.0         20841.0                      2273855.0
#
#             global_south_new_editor_retention  global_south_nonbot_edits  \
# month
# 2018-01-01 NaN                                NaN
# 2018-02-01 NaN                                NaN
# 2018-03-01 NaN                                NaN
# 2018-04-01 NaN                                NaN
# 2018-05-01 NaN                                NaN
# 2018-06-01  0.044275                          NaN
# 2018-07-01  0.042536                          NaN
