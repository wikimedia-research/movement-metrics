# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager
import os
from os.path import dirname

# %%
#step 0 - git pull to stay up to date with the repo on Github
#Step 1 - make sure that there's data on the API --- see emails in the product analytics email account
#Step 2 - run the four notebooks noted below on a stat box

# %%
# %run '02a-calculation.ipynb'
# Out:
# Running active_editors on hive...
# SPARK_HOME: /usr/lib/spark3
# Using Hadoop client lib jars at 3.2.0, provided by Spark.
# PYSPARK_PYTHON=/opt/conda-analytics/bin/python3
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/06/20 21:59:47 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# 23/06/20 21:59:47 WARN Utils: Service 'sparkDriver' could not bind on port 12000. Attempting port 12001.
# 23/06/20 21:59:47 WARN Utils: Service 'sparkDriver' could not bind on port 12001. Attempting port 12002.
# 23/06/20 21:59:48 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 23/06/20 21:59:48 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 23/06/20 21:59:57 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13000. Attempting port 13001.
# 23/06/20 21:59:57 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13001. Attempting port 13002.
# 23/06/20 21:59:57 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Attempted to request executors before the AM has registered!
# 23/06/20 22:00:09 WARN SharedInMemoryCache: Evicting cached table partition metadata from memory due to size constraints (spark.sql.hive.filesourcePartitionFileCacheSize = 262144000 bytes). This may impact query planning performance.
# Running edits on hive...
# 23/06/20 22:00:50 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# Running new_editor_retention on hive...
# Running global_south_edits_editors on hive...
# Running mobile-heavy_edits_editors on hive...
# Running mobile-heavy_new_editor_retention on hive...
# Running global_south_new_editor_retention on hive...
# Now on the 0th project of 333 (aa.wikipedia.org)
# Now on the 10th project of 333 (ang.wikipedia.org)
# Now on the 20th project of 333 (avk.wikipedia.org)
# Now on the 30th project of 333 (bcl.wikipedia.org)
# Now on the 40th project of 333 (bo.wikipedia.org)
# Now on the 50th project of 333 (ce.wikipedia.org)
# Now on the 60th project of 333 (cs.wikipedia.org)
# Now on the 70th project of 333 (dty.wikipedia.org)
# Now on the 80th project of 333 (eu.wikipedia.org)
# Now on the 90th project of 333 (frr.wikipedia.org)
# Now on the 100th project of 333 (gl.wikipedia.org)
# Now on the 110th project of 333 (hak.wikipedia.org)
# Now on the 120th project of 333 (hu.wikipedia.org)
# Now on the 130th project of 333 (ilo.wikipedia.org)
# Now on the 140th project of 333 (kaa.wikipedia.org)
# Now on the 150th project of 333 (kl.wikipedia.org)
# Now on the 160th project of 333 (kv.wikipedia.org)
# Now on the 170th project of 333 (lij.wikipedia.org)
# Now on the 180th project of 333 (mad.wikipedia.org)
# Now on the 190th project of 333 (ml.wikipedia.org)
# Now on the 200th project of 333 (myv.wikipedia.org)
# Now on the 210th project of 333 (ng.wikipedia.org)
# Now on the 220th project of 333 (ny.wikipedia.org)
# Now on the 230th project of 333 (pcd.wikipedia.org)
# Now on the 240th project of 333 (ps.wikipedia.org)
# Now on the 250th project of 333 (rue.wikipedia.org)
# Now on the 260th project of 333 (se.wikipedia.org)
# Now on the 270th project of 333 (smn.wikipedia.org)
lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_south_new_editor_retention on hive...
# /home/iflorez/.conda/envs/2023-03-31T21.45.57_iflorez/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_south_net_new_content on hive...
# /home/iflorez/.conda/envs/2023-03-31T21.45.57_iflorez/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_south_wikidata_entities on hive...
# /home/iflorez/.conda/envs/2023-03-31T21.45.57_iflorez/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_north_edits_editors on hive...
# /home/iflorez/.conda/envs/2023-03-31T21.45.57_iflorez/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_north_new_editor_retention on hive...
# /home/iflorez/.conda/envs/2023-03-31T21.45.57_iflorez/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_north_net_new_content on hive...
# /home/iflorez/.conda/envs/2023-03-31T21.45.57_iflorez/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Running global_north_wikidata_entities on hive...
# /home/iflorez/.conda/envs/2023-03-31T21.45.57_iflorez/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#             global_north_active_editors  global_north_edits  \
# month
# 2023-01-01  63611.0                      23132571.0
# 2023-02-01  58566.0                      20435724.0
# 2023-03-01  62122.0                      20237544.0
# 2023-04-01  60511.0                      22506527.0
# 2023-05-01  61101.0                      23831841.0
#
#             global_north_net_new_content  global_north_new_editor_retention  \
# month
# 2023-01-01  1369972.0                    NaN
# 2023-02-01  1098400.0                    NaN
# 2023-03-01  1191979.0                    NaN
# 2023-04-01  1339595.0                    NaN
# 2023-05-01  2439208.0                    NaN
#
#             global_north_nonbot_edits  global_north_wikidata_entities  \
# month
# 2023-01-01  14379615.0                 486309.0
# 2023-02-01  11799328.0                 357345.0
# 2023-03-01  12261556.0                 339707.0
# 2023-04-01  12251552.0                 421655.0
# 2023-05-01  12512159.0                 686609.0
#
#             global_south_active_editors  global_south_edits  \
# month
# 2023-01-01  20808.0                      4040347.0
# 2023-02-01  19642.0                      3942811.0
# 2023-03-01  20763.0                      4015257.0
# 2023-04-01  20411.0                      2978178.0
# 2023-05-01  20267.0                      2828472.0
#
#             global_south_net_new_content  global_south_new_editor_retention  \
# month
# 2023-01-01  393904.0                     NaN
# 2023-02-01  225253.0                     NaN
# 2023-03-01  382678.0                     NaN
# 2023-04-01  373579.0                     NaN
# 2023-05-01  252402.0                     NaN
#
#             global_south_nonbot_edits  global_south_wikidata_entities
# month
# 2023-01-01  2754632.0                  149483.0
# 2023-02-01  2533307.0                  24063.0
# 2023-03-01  2752975.0                  36224.0
# 2023-04-01  2689331.0                  41170.0
# 2023-05-01  2582733.0                  25832.0

# %%
#TODO get ouput here 
# %run '03a-report.ipynb'
# Out:
# Monthly report
# Previous month's report

# %%
# see the repo for further documentation
data_path = "../metrics/metrics.tsv"
# %run wikicharts/EDITOR_CONTENT_METRICS.ipynb
# Out:
# Changing directory to:/srv/home/iflorez/key metrics/Editing-movement-metrics/wikicharts
# Generating Active Editors chart...
# Generating New Returning chart...
# Generating Net New Content chart...
# Resetting directory to:/srv/home/iflorez/key metrics/Editing-movement-metrics/wikicharts

# %%
# proceed to step 4 as noted in the readme file
