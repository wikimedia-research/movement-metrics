# %%
from urllib import request
import json

import pandas as pd
from wmfdata import mariadb, hive, utils, charting
# Out:
# You can find the source for `wmfdata` at https://github.com/neilpquinn/wmfdata

# %% [markdown]
# # Mobile pageviews per country for mobile-heavy wikis

# %%
iso_3166_url = "https://raw.githubusercontent.com/umpirsky/country-list/master/data/en/country.json"
country_codes = json.loads(
    request.urlopen(iso_3166_url).read().decode()
)

# %%
mh_wikis = {
    'hi.wikipedia': 'Hindi Wikipedia',
    'bn.wikipedia': 'Bangla Wikipedia',
    'id.wikipedia': 'Indonesian Wikipedia',
    'ar.wikipedia': 'Arabic Wikipedia',
    'mr.wikipedia': 'Marathi Wikipedia',
    'fa.wikipedia': 'Persian Wikipedia',
    'sw.wikipedia': 'Swahili Wikipedia',
    'tl.wikipedia': 'Tagalog Wikipedia',
    'zh.wikiquote': 'Chinese Wikiquote',
    'th.wikipedia': 'Thai Wikipedia',
    'arz.wikipedia': 'Egyptian Arabic Wikipedia',
    'ml.wikipedia': 'Malayalam Wikipedia',
    'ta.wikipedia': 'Tamil Wikipedia',
    'kn.wikipedia': 'Kannada Wikipedia',
    'pt.wiktionary': 'Portuguese Wiktionary',
    'az.wikipedia': 'Azerbaijani Wikipedia',
    'gu.wikipedia': 'Gujarati Wikipedia',
    'ky.wikipedia': 'Kyrgyz Wikipedia',
    'sq.wikipedia': 'Albanian Wikipedia',
    'ms.wikipedia': 'Malay Wikipedia'
}

mh_domains = mh_wikis.keys()
mh_sql_tuple = "(" + ", ".join('"{}"'.format(d) for d in mh_domains)  + ")"

# %%
mh_sql_tuple
# Out:
# '("ms.wikipedia", "az.wikipedia", "sw.wikipedia", "ar.wikipedia", "bn.wikipedia", "ky.wikipedia", "pt.wiktionary", "sq.wikipedia", "zh.wikiquote", "mr.wikipedia", "fa.wikipedia", "th.wikipedia", "hi.wikipedia", "id.wikipedia", "arz.wikipedia", "tl.wikipedia", "ml.wikipedia", "kn.wikipedia", "gu.wikipedia", "ta.wikipedia")'

# %%
mh_views = hive.run("""
select project, country_code, sum(view_count) as pageviews
from wmf.projectview_hourly
where
    ((year = 2017 and month >= 9) or (year = 2018 and month < 9)) and
    access_method in ("mobile web", "mobile app") and
    project in {projects}
group by project, country_code
""".format(projects = mh_sql_tuple))

# %%
mh_views_2 = mh_views

# %%
mh_views_2["project"] = mh_views_2["project"].apply(mh_wikis.get)

# %%
mh_views_2["country_code"] = mh_views_2["country_code"].apply(country_codes.get)

# %%
piv = mh_views_2.pivot_table("pageviews", index="project", columns="country_code", aggfunc="sum", fill_value=0)

# %%
countries_sorted = piv.apply("sum", axis=0).sort_values(ascending=False).index

# %% [markdown]
# piv = piv.reindex(labels=countries_sorted, axis="columns")

# %%
with pd.option_context(
    'display.max_rows', None, 
    'display.max_columns', None,
    'display.max_colwidth', 500,
):
    display(piv.iloc[:, :25])
# Out:
# country_code               Indonesia       Iran  United States      India  \
# project
# Albanian Wikipedia             15447       8713        3396898      65797
# Arabic Wikipedia             1151769    4006381      167810957    2338849
# Azerbaijani Wikipedia          43929     194307        5550842     262200
# Bangla Wikipedia              109311       8549       62374318   17588054
# Chinese Wikiquote               2660        662         332425       2734
# Egyptian Arabic Wikipedia      16764     112533        3942348      39869
# Gujarati Wikipedia              4867        627        2201941    7966028
# Hindi Wikipedia               446175      14139       84437246  407428758
# Indonesian Wikipedia       906065426      90411      279737727    5756010
# Kannada Wikipedia               8992        850        4390847   14166202
# Kyrgyz Wikipedia                1445       1384        1075773      11088
# Malay Wikipedia              5096344      16760       10617898     368994
# Malayalam Wikipedia            22070       2019        9296542   21381036
# Marathi Wikipedia              46093       1439       13287866   42252021
# Persian Wikipedia             199279  838131997       76797259    1379576
# Portuguese Wiktionary           3497       1027        7865612       7599
# Swahili Wikipedia              14907       1803        5415616      31251
# Tagalog Wikipedia              29236       5264       29856265      53804
# Tamil Wikipedia                47874       3729       11976827   34718483
# Thai Wikipedia                200263      10899       20770409     188578
#
# country_code                Thailand  Saudi Arabia      Egypt    Morocco  \
# project
# Albanian Wikipedia              5813         11405       4935       8747
# Arabic Wikipedia              508856     353895675  203461036  171389017
# Azerbaijani Wikipedia          19262         21945      22779      76259
# Bangla Wikipedia                6768        745487       6779      21187
# Chinese Wikiquote               5047           473        570       1890
# Egyptian Arabic Wikipedia       5301       2453622    6394481    1255516
# Gujarati Wikipedia              1177          1723        252       1076
# Hindi Wikipedia                31238        316923       4587      17324
# Indonesian Wikipedia          465882        590141     345732     115953
# Kannada Wikipedia               1003          7653        300       1764
# Kyrgyz Wikipedia                 691           519       1171        859
# Malay Wikipedia               169109         98809     109034      35765
# Malayalam Wikipedia             2326        660256       1706       3231
# Marathi Wikipedia               1711          7323        512       2537
# Persian Wikipedia             122171        236426     116081     327267
# Portuguese Wiktionary           1611           603       1033       5184
# Swahili Wikipedia               2315          3071       7612       4121
# Tagalog Wikipedia              13947        147586       2635      14312
# Tamil Wikipedia                 8128        219813       1903       6021
# Thai Wikipedia             449175971         20493      46838      18396
#
# country_code                 Algeria      Iraq  Malaysia  \
# project
# Albanian Wikipedia              3929     11415      4315
# Arabic Wikipedia           114022000  89726984   1614239
# Azerbaijani Wikipedia          21246     33650     10834
# Bangla Wikipedia                6046     23141    333094
# Chinese Wikiquote                653       336     53932
# Egyptian Arabic Wikipedia    1188503   1225630     20817
# Gujarati Wikipedia               248       178       396
# Hindi Wikipedia                 8498      6126     51018
# Indonesian Wikipedia           61941    125470  13131952
# Kannada Wikipedia                367       262       879
# Kyrgyz Wikipedia                 291       302       381
# Malay Wikipedia                16002      8250  71329751
# Malayalam Wikipedia             1157      1761     11943
# Marathi Wikipedia                540       317      1453
# Persian Wikipedia             146543   1424827    245459
# Portuguese Wiktionary           1257       331      1092
# Swahili Wikipedia               1494      2520      3030
# Tagalog Wikipedia               3385      1550     25274
# Tamil Wikipedia                 2485      2803    544281
# Thai Wikipedia                  4373      3204    503677
#
# country_code               United Arab Emirates    Jordan   Germany  \
# project
# Albanian Wikipedia                         9708      1746   1285392
# Arabic Wikipedia                       41121271  69487144  24336244
# Azerbaijani Wikipedia                     35866      6370    905263
# Bangla Wikipedia                         231710     18053    355154
# Chinese Wikiquote                           661       111    104393
# Egyptian Arabic Wikipedia                382221    780553    447526
# Gujarati Wikipedia                         2400        66    102185
# Hindi Wikipedia                          251392      4653    316896
# Indonesian Wikipedia                     154597     51542   1596125
# Kannada Wikipedia                          9001        77    103961
# Kyrgyz Wikipedia                           1467       381    169511
# Malay Wikipedia                           27292     20950    408605
# Malayalam Wikipedia                      755682      1459    201612
# Marathi Wikipedia                         10860       256    207671
# Persian Wikipedia                      34451501    311751  32810617
# Portuguese Wiktionary                       692       111    313770
# Swahili Wikipedia                          4459       534    203723
# Tagalog Wikipedia                        119253      5233    310608
# Tamil Wikipedia                          270318      1941    561652
# Thai Wikipedia                            78753     14890    926592
#
# country_code               Azerbaijan  United Kingdom    Kuwait  Netherlands  \
# project
# Albanian Wikipedia               6849          596130      1903        64473
# Arabic Wikipedia               245688        16465092  50670514      5821996
# Azerbaijani Wikipedia        57103803         1070811      5987     21865316
# Bangla Wikipedia                 1372         3827503    195555        50011
# Chinese Wikiquote                  79           18794       108         4212
# Egyptian Arabic Wikipedia        2114          264018    557770       133703
# Gujarati Wikipedia                 62           33215       913         1567
# Hindi Wikipedia                  1107          412549    113930        43555
# Indonesian Wikipedia            25924         3228175     43659       670726
# Kannada Wikipedia                  70           36684      1990         3881
# Kyrgyz Wikipedia                 1206           23396       173         4737
# Malay Wikipedia                  4557          888671      5812        41363
# Malayalam Wikipedia               341          226008    200629        14145
# Marathi Wikipedia                 115          171675      2513        11648
# Persian Wikipedia              257812        25501221    320352     19404635
# Portuguese Wiktionary             247           25106       122         6878
# Swahili Wikipedia                 516          455127       469        80051
# Tagalog Wikipedia                1124          537193     45773        39930
# Tamil Wikipedia                   714          248820    138140        24761
# Thai Wikipedia                   1677         1233514     12417       195129
#
# country_code               Bangladesh     Syria     Sudan  Philippines  \
# project
# Albanian Wikipedia               3807       503       565         4394
# Arabic Wikipedia               229254  44536036  36370391       192834
# Azerbaijani Wikipedia           15175      3704      4454         6741
# Bangla Wikipedia             45444666       234      4129         2777
# Chinese Wikiquote                 724        37        75         2159
# Egyptian Arabic Wikipedia        2175    624326    394582         2272
# Gujarati Wikipedia                754        30       105          411
# Hindi Wikipedia                 28372       667      1832         4451
# Indonesian Wikipedia            97645     11890     48414       184358
# Kannada Wikipedia                1052        38       229          354
# Kyrgyz Wikipedia                  219        33        55          168
# Malay Wikipedia                 26836      1633      3997        27754
# Malayalam Wikipedia              2778       133       608          817
# Marathi Wikipedia                2185        50       221          757
# Persian Wikipedia               34341     56503     36705        38690
# Portuguese Wiktionary             775        64        79          635
# Swahili Wikipedia                1393       993      2522         1325
# Tagalog Wikipedia                2689       225       763     32247578
# Tamil Wikipedia                  8121       109      1422         3215
# Thai Wikipedia                  12555       282      8323        73946
#
# country_code                Tunisia  Palestinian Territories   Lebanon
# project
# Albanian Wikipedia             1556                      347      1102
# Arabic Wikipedia           31676239                 29754414  27487111
# Azerbaijani Wikipedia          7068                     1505      5028
# Bangla Wikipedia                892                      163     22834
# Chinese Wikiquote               151                       15        64
# Egyptian Arabic Wikipedia    362210                   342224    408114
# Gujarati Wikipedia               67                        5        45
# Hindi Wikipedia                2074                      597      1686
# Indonesian Wikipedia          31134                    24471     44318
# Kannada Wikipedia                76                       10        39
# Kyrgyz Wikipedia                 63                        7        61
# Malay Wikipedia                4819                      830     10062
# Malayalam Wikipedia             421                      128      1287
# Marathi Wikipedia               151                      130        78
# Persian Wikipedia             43600                     8865     62664
# Portuguese Wiktionary           322                      110       336
# Swahili Wikipedia               529                      109       816
# Tagalog Wikipedia               823                       96      5397
# Tamil Wikipedia                 396                       86      1338
# Thai Wikipedia                 1778                      246      1820

# %% [markdown]
# # Monthly editors per country

# %%
toby_countries = [
    "China", "India", "United States", "Indonesia", "Brazil", "Pakistan", "Nigeria",
    "Bangladesh", "Russia", "Mexico", "Japan", "Philippines", "Ethiopia", "Vietnam",
    "Egypt", "Germany", "Iran", "Turkey", "Democratic Republic of the Congo",
    "Thailand", "United Kingdom", "France", "Italy", "Tanzania", "South Africa",
    "Myanmar", "South Korea", "Colombia", "Kenya", "Spain", "Ukraine", "Argentina",
    "Sudan", "Algeria", "Uganda", "Poland", "Iraq", "Canada", "Morocco",
    "Afghanistan", "Saudi Arabia", "Peru", "Venezuela", "Malaysia", "Uzbekistan",
    "Nepal", "Mozambique", "Ghana", "Yemen", "Angola", "Madagascar", "Australia",
    "Cameroon", "Ivory Coast", "Sri Lanka", "Niger", "Romania", "Burkina Faso",
    "Syria", "Mali", "Chile", "Kazakhstan", "Malawi", "Netherlands", "Zambia",
    "Guatemala", "Ecuador", "Zimbabwe", "Cambodia", "Senegal", "Chad", "Guinea",
    "South Sudan", "Rwanda", "Burundi", "Cuba", "Tunisia", "Belgium", "Benin",
    "Somalia", "Greece", "Bolivia", "Haiti", "Dominican Republic", "Czech Republic",
    "Portugal", "Azerbaijan", "Sweden", "Hungary", "Belarus", "United Arab Emirates",
    "Serbia", "Tajikistan", "Austria", "Switzerland", "Israel",
    "Honduras", "Papua New Guinea", "Jordan", "Togo", "Hong Kong", "Bulgaria",
    "Paraguay", "Sierra Leone", "Libya", "Nicaragua", "El Salvador", "Kyrgyzstan",
    "Lebanon", "Singapore", "Denmark", "Finland", "Turkmenistan", "Slovakia",
    "Eritrea", "Norway", "Central African Republic", "Costa Rica",
    "Republic of the Congo", "Ireland", "Oman", "Liberia", "New Zealand", "Croatia", "Mauritania",
    "Moldova", "Kuwait", "Panama", "Georgia", "Bosnia and Herzegovina", "Puerto Rico",
    "Uruguay", "Armenia", "Mongolia", "Albania", "Lithuania", "Jamaica",
    "Namibia", "Botswana", "Qatar", "Lesotho", "Macedonia", "Slovenia", "Gambia",
    "Latvia", "Guinea-Bissau", "Gabon", "Bahrain", "Trinidad and Tobago", "Estonia",
    "Swaziland", "Mauritius", "East Timor", "Cyprus", "Djibouti", "Fiji",
    "Equatorial Guinea", "Comoros", "Bhutan", "Guyana", "Montenegro", 
    "Solomon Islands", "Luxembourg", "Suriname", "Malta", "Bahamas", "Maldives", "Belize",
    "Iceland", "French Polynesia", "Barbados", "Vanuatu", "New Caledonia", "Samoa",
    "Sao Tome and Principe", "Saint Lucia", "Guam", "Kiribati", "Grenada", "Tonga",
    "United States Virgin Islands", "Aruba", "Seychelles", "Antigua and Barbuda",
    "Dominica", "Andorra", "Bermuda", "Cayman Islands", "Greenland",
    "Saint Kitts and Nevis", "Marshall Islands", "Monaco", "Liechtenstein", "Taiwan", "Unknown"
]

# %%
co_eds_r = hive.run("""
select
    country_code,
    sum(distinct_editors) / 8 as monthly_editors,
    sum(if(users_are_anonymous = false, distinct_editors, 0)) / 8 as monthly_registered_editors
from wmf.geoeditors_monthly
where 
    month >= "2018-01" and
    month < "2018-09"
group by country_code
""")

co_eds = co_eds_r.copy()
co_eds["country_code"] = co_eds["country_code"].apply(country_codes.get)

co_eds.head()
# Out:
#            country_code  monthly_editors  monthly_registered_editors
# 0                  None         10109.25                    9488.750
# 1               Andorra            71.00                      22.875
# 2  United Arab Emirates          3204.75                     950.125
# 3           Afghanistan           381.00                     144.375
# 4     Antigua & Barbuda            20.75                       5.875

# %%
co_eds.query("country_code.isnull()")
# Out:
#    country_code  monthly_editors  monthly_registered_editors
# 0          None        10109.250                    9488.750
# 34         None            0.125                       0.125

# %%
co_eds = co_eds.drop([34])

# %%
toby_transforms = {
    "Antigua & Barbuda": "Antigua and Barbuda",
    "Bosnia & Herzegovina": "Bosnia and Herzegovina",
    "Myanmar (Burma)": "Myanmar",
    "Trinidad & Tobago": "Trinidad and Tobago",
    "Congo - Kinshasa": "Democratic Republic of the Congo",
    "Congo - Brazzaville": "Republic of the Congo",
    "Côte d’Ivoire": "Ivory Coast",
    "Czechia": "Czech Republic",
    "Hong Kong SAR China": "Hong Kong",
    "São Tomé & Príncipe": "Sao Tome and Principe",
    "Timor-Leste": "East Timor",
    None: "Unknown"
}

# %%
co_eds = co_eds.replace(to_replace=toby_transforms)

# %%
with pd.option_context(
    'display.max_rows', None, 
    'display.max_columns', None,
    'display.max_colwidth', 500,
):
    display(co_eds.query("country_code not in @toby_countries").sort_values("monthly_editors", ascending=False))
# Out:
#                        country_code  monthly_editors  \
# 145                 Macau SAR China          450.375
# 180         Palestinian Territories          431.750
# 185                         Réunion          264.375
# 28                           Brunei          126.500
# 123                            Laos          120.500
# 87                       Guadeloupe          116.750
# 147                      Martinique          106.500
# 102                     Isle of Man          104.750
# 109                          Jersey           77.125
# 74                    Faroe Islands           66.250
# 80                    French Guiana           57.000
# 239                          Kosovo           54.000
# 81                         Guernsey           50.500
# 53                          Curaçao           47.250
# 83                        Gibraltar           43.125
# 52                       Cape Verde           32.500
# 125                       St. Lucia           32.250
# 15                    Åland Islands           32.125
# 241                         Mayotte           30.000
# 146        Northern Mariana Islands           20.500
# 201                      San Marino           17.750
# 30            Caribbean Netherlands           15.625
# 234             U.S. Virgin Islands           15.625
# 231        St. Vincent & Grenadines           13.250
# 211          Turks & Caicos Islands           11.000
# 208                    Sint Maarten           10.750
# 230                    Vatican City           10.750
# 118               St. Kitts & Nevis            9.375
# 233          British Virgin Islands            5.000
# 11                   American Samoa            5.000
# 138                      St. Martin            4.250
# 26                   St. Barthélemy            4.250
# 5                          Anguilla            3.875
# 177           St. Pierre & Miquelon            3.875
# 182                           Palau            3.875
# 45                     Cook Islands            3.875
# 73                       Micronesia            3.125
# 39          Cocos (Keeling) Islands            1.625
# 149                      Montserrat            1.250
# 104  British Indian Ocean Territory            1.000
# 166                           Nauru            0.750
# 72                 Falkland Islands            0.750
# 167                            Niue            0.750
# 196                      St. Helena            0.625
# 237                 Wallis & Futuna            0.625
# 54                 Christmas Island            0.500
# 160                  Norfolk Island            0.500
# 66                   Western Sahara            0.375
# 222                          Tuvalu            0.250
# 198            Svalbard & Jan Mayen            0.125
# 9                        Antarctica            0.125
# 178                Pitcairn Islands            0.125
#
#      monthly_registered_editors
# 145                     120.750
# 180                     141.875
# 185                      95.750
# 28                       27.125
# 123                      32.625
# 87                       27.125
# 147                      32.750
# 102                      28.125
# 109                      27.750
# 74                       23.125
# 80                       19.125
# 239                      22.125
# 81                       14.875
# 53                       14.000
# 83                       12.625
# 52                       10.625
# 125                       8.625
# 15                       10.625
# 241                      16.375
# 146                       3.625
# 201                       6.750
# 30                        5.625
# 234                       4.500
# 231                       2.500
# 211                       2.750
# 208                       3.500
# 230                       3.625
# 118                       2.875
# 233                       1.750
# 11                        1.250
# 138                       1.375
# 26                        1.250
# 5                         1.125
# 177                       0.625
# 182                       0.875
# 45                        0.375
# 73                        0.875
# 39                        1.125
# 149                       0.750
# 104                       0.375
# 166                       0.375
# 72                        0.250
# 167                       0.375
# 196                       0.125
# 237                       0.125
# 54                        0.125
# 160                       0.375
# 66                        0.250
# 222                       0.125
# 198                       0.000
# 9                         0.125
# 178                       0.000

# %%
toby_co_eds = co_eds.set_index("country_code").reindex(toby_countries)
toby_co_eds.head(10)
# Out:
#                monthly_editors  monthly_registered_editors
# country_code
# China                 6213.875                    2978.250
# India                59107.000                   18885.250
# United States       199287.625                   64144.000
# Indonesia            11170.250                    3839.250
# Brazil               34509.875                    7805.375
# Pakistan              5712.375                    1931.375
# Nigeria               1699.500                    1025.500
# Bangladesh            4348.875                    2017.375
# Russia               42076.000                   12119.500
# Mexico               18861.000                    3504.250

# %%
toby_co_eds.loc["Taiwan"]
# Out:
# monthly_editors               17995.00
# monthly_registered_editors     4505.75
# Name: Taiwan, dtype: float64

# %% [markdown]
# # Monthly unique devices per country

# %%
co_uds_r = hive.run("""
select
    country_code,
    country,
    sum(uniques_estimate) / 12 as monthly_unique_devices
from wmf.unique_devices_per_domain_monthly
where
    ((year = 2017 and month >= 9) or (year = 2018 and month < 9))
group by country_code, country
""")

# %%
co_uds = co_uds_r.drop("country", axis=1)

# %%
co_uds["country_code"] = co_uds["country_code"].apply(country_codes.get)

# %%
co_uds = co_uds.replace(to_replace=toby_transforms)

# %%
toby_co_uds = co_uds.groupby("country_code").sum().reindex(labels=toby_countries, axis="index")

# %%
toby_co_uds.head(10)
# Out:
#                monthly_unique_devices
# country_code
# China                    2.870796e+07
# India                    1.174716e+08
# United States            3.433378e+08
# Indonesia                3.508375e+07
# Brazil                   6.044463e+07
# Pakistan                 8.057592e+06
# Nigeria                  5.066659e+06
# Bangladesh               4.326530e+06
# Russia                   6.913504e+07
# Mexico                   4.447441e+07
